# %%
class Student:
    pass

# %%
s=Student()

# %%
print(type(s))
# Out:
# <class '__main__.Student'>

# %%
x=10

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
class Student:
    def __init__(self,id,name):
        self.id=id
        self.name=name
    def std_info(self):
        print(f"Id:{self.id} name:{self.name}")

# %%
s1=Student(1,"joe")

# %%
s1.std_info()
# Out:
# Id:1 name:joe

# %%
#to hide id and name we are using double underscore

# %%
class Student:
    def __init__(self,id,name):
        self.__id=id
        self.__name=name
    def std_info(self):
        print(f"Id:{self.id} name:{self.name}")

# %%
s1=Student(1,"joe")

# %%
s1.id=100

# %%
class Bank:
    name="joe"
    __balance=50000

# %%
b=Bank()

# %%
class Bank:
    name="joe"
    balance=50000

# %%
b=Bank()

# %%
class Customer:
    id=0
    name=None
    address=None
    __email=None
    __contact=None

# %%
c=Customer()

# %%
class Customer:
    def __init__(self,id,name,address):
        self.id=id
        self.name=name
        self.address=address
    def cust_info(self):
        print(f"id{self.id} name{self.name} address{self.address}")

# %%
c=Customer(100,"joe","kerala")

# %%
class Cart:
    def __init__(self,name,code,price,qty,total):
        self.name=name
        self.code=code
        self.price=price
        self.qty=qty
        self.total=total
    def calculate_total(self):
        return self.qty*self.price
    def display

# %%
class Bank:
    def __init__(self,amount):
        self.amount=amount

# %%
b=Bank(1000)
