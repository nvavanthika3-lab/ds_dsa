# %%
from sklearn.linear_model import LinearRegression

# %%
import pandas as pd

# %%
rd=pd.DataFrame(
    {'hr':[1,2,3,4,5],
    'mark':[35,40,45,50,65]
    })

# %%
rd
# Out:
#    hr  mark
# 0   1    35
# 1   2    40
# 2   3    45
# 3   4    50
# 4   5    65

# %%
x=rd[['hr']]
y=rd['mark']

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
pr=model.predict([[8]])
# Out:
# c:\ds_dsa\ds_env\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"

# %%
pr
# Out:
# array([82.])

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
import pandas as pd

# %%
x=[[23,3000],
   [31,4100],
   [30,5000],
   [31,6000]]
y=['yes','no','yes','yes']

# %%
model=DecisionTreeClassifier()

# %%
model.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
pr=model.predict([[35,7000]])

# %%
pr
# Out:
# array(['yes'], dtype='<U3')
